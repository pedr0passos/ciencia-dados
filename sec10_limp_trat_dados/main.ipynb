# %%
# importancao das bibliotecas

import pandas as pd
import seaborn as sb
import statistics as st

# %%
# importacao dos conjuntos de dados

data = pd.read_csv('Churn.csv', sep=';')
data.head()
# Out:
#    X0   X1  X2        X3  X4  X4.1        X6  X7  X8  X9         X10  X11
# 0   1  619  RS  Feminino  42     2         0   1   1   1  10134888.0    1
# 1   2  608  SC  Feminino  41     1   8380786   1   0   1  11254258.0    0
# 2   3  502  RS  Feminino  42     8   1596608   3   1   0  11393157.0    1
# 3   4  699  RS  Feminino  39     1         0   2   0   0   9382663.0    0
# 4   5  850  SC  Feminino  43     2  12551082   1   1   1    790841.0    0

# %%
# tamanho da tabela de dados
data.shape
# Out:
# (999, 12)

# %%
# renomeando as colunas
data.columns = ['Id', 'Score', 'Estado', 'Genero', 'Idade', 'Patrimonio', 'Saldo', 'Produtos', 'TemCartCredito', 'Ativo', 'Salario', 'Saiu']
# visualizando
data.head()
# Out:
#    Id  Score Estado    Genero  Idade  Patrimonio     Saldo  Produtos  \
# 0   1    619     RS  Feminino     42           2         0         1
# 1   2    608     SC  Feminino     41           1   8380786         1
# 2   3    502     RS  Feminino     42           8   1596608         3
# 3   4    699     RS  Feminino     39           1         0         2
# 4   5    850     SC  Feminino     43           2  12551082         1
#
#    TemCartCredito  Ativo     Salario  Saiu
# 0               1      1  10134888.0     1
# 1               0      1  11254258.0     0
# 2               1      0  11393157.0     1
# 3               0      0   9382663.0     0
# 4               1      1    790841.0     0

# %%
# explorar dados e categorias

# estado
agrupado = data.groupby(['Estado']).size()
agrupado
# Out:
# Estado
# PR    257
# RP      1
# RS    478
# SC    258
# SP      4
# TD      1
# dtype: int64

# %%
agrupado.plot.bar(color = 'black')
# Out:
# <AxesSubplot:xlabel='Estado'>

# %%
# genero
agrupado = data.groupby(['Genero']).size()
agrupado
# Out:
# Genero
# F              2
# Fem            1
# Feminino     461
# M              6
# Masculino    521
# dtype: int64

# %%
agrupado.plot.bar(color = 'black')
# Out:
# <AxesSubplot:xlabel='Genero'>

# %%
# explorando colunas numéricas

# score
data['Score'].describe()
# Out:
# count    999.000000
# mean     648.621622
# std       98.264219
# min      376.000000
# 25%      580.000000
# 50%      653.000000
# 75%      721.000000
# max      850.000000
# Name: Score, dtype: float64

# %%
sb.boxplot(data['Score']).set_title('Score')
# Out:
# C:\Users\rocha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Score')

# %%
sb.distplot(data['Score']).set_title('Score')
# Out:
# C:\Users\rocha\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Score')

# %%
# idade
data['Idade'].describe()
# Out:
# count    999.000000
# mean      38.902903
# std       11.401912
# min      -20.000000
# 25%       32.000000
# 50%       37.000000
# 75%       44.000000
# max      140.000000
# Name: Idade, dtype: float64

# %%
sb.boxplot(data['Idade']).set_title('Idade')
# Out:
# C:\Users\rocha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Idade')

# %%
sb.distplot(data['Idade']).set_title('Idade')
# Out:
# C:\Users\rocha\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Idade')

# %%
# saldo

data['Saldo'].describe()
# Out:
# count    9.990000e+02
# mean     7.164928e+06
# std      6.311840e+06
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      8.958835e+06
# 75%      1.258684e+07
# max      2.117743e+07
# Name: Saldo, dtype: float64

# %%
sb.boxplot(data['Saldo']).set_title('Saldo')
# Out:
# C:\Users\rocha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Saldo')

# %%
sb.distplot(data['Saldo']).set_title('Saldo')
# Out:
# C:\Users\rocha\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Saldo')

# %%
# salario

data['Salario'].describe()
# Out:
# count    9.920000e+02
# mean     3.528762e+07
# std      5.305800e+08
# min      9.677000e+03
# 25%      3.029011e+06
# 50%      8.703250e+06
# 75%      1.405213e+07
# max      1.193469e+10
# Name: Salario, dtype: float64

# %%
sb.boxplot(data['Salario']).set_title('Salario')
# Out:
# C:\Users\rocha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Salario')

# %%
sb.distplot(data['Salario']).set_title('Salario')
# Out:
# C:\Users\rocha\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Salario')

# %%
# contamos valores NAN

#genero e salario
data.isnull().sum()
# Out:
# Id                0
# Score             0
# Estado            0
# Genero            8
# Idade             0
# Patrimonio        0
# Saldo             0
# Produtos          0
# TemCartCredito    0
# Ativo             0
# Salario           7
# Saiu              0
# dtype: int64

# %%
# salarios

#remover nas e substituir por mediana
data['Salario'].describe()
# Out:
# count    9.920000e+02
# mean     3.528762e+07
# std      5.305800e+08
# min      9.677000e+03
# 25%      3.029011e+06
# 50%      8.703250e+06
# 75%      1.405213e+07
# max      1.193469e+10
# Name: Salario, dtype: float64
