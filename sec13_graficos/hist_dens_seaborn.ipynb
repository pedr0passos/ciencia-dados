# %%
import pandas as pd
import seaborn as srn
import matplotlib.pyplot as plt
# carregamento de outra base de dados
data = pd.read_csv('chicken.csv')
data
# Out:
#     weight       feed
# 0      179  horsebean
# 1      160  horsebean
# 2      136  horsebean
# 3      227  horsebean
# 4      217  horsebean
# ..     ...        ...
# 66     359     casein
# 67     216     casein
# 68     222     casein
# 69     283     casein
# 70     332     casein
#
# [71 rows x 2 columns]

# %%
# criacao de um novo dataframe agrupando o atributo "feed"
agrupado = data.groupby(['feed'])['weight'].sum()
agrupado
# Out:
# feed
# casein       3883
# horsebean    1602
# linseed      2625
# meatmeal     3046
# soybean      3450
# sunflower    3947
# Name: weight, dtype: int64

# %%
# novo dataframe somente para testar os filtros do pandas
teste = data.loc[data['feed'] == 'horsebean']
teste
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean
# 5     168  horsebean
# 6     108  horsebean
# 7     124  horsebean
# 8     143  horsebean
# 9     140  horsebean

# %%
sb.distplot(teste.weight, hist = False).set_title('horsebean')
# Out:
# C:\Users\rocha\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'horsebean')

# %%
# mudando para caseina
teste = data.loc[data['feed'] == 'casein']
teste
# Out:
#     weight    feed
# 59     368  casein
# 60     390  casein
# 61     379  casein
# 62     260  casein
# 63     404  casein
# 64     318  casein
# 65     352  casein
# 66     359  casein
# 67     216  casein
# 68     222  casein
# 69     283  casein
# 70     332  casein

# %%
sb.distplot(teste.weight).set_title('Caseina')
# Out:
# C:\Users\rocha\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Caseina')

# %%
plt.figure()
plt.subplot(3,2,1)
srn.distplot(data.loc[data['feed'] == 'horsebean'].weight, hist = False).set_title('Horsebean')
plt.subplot(3,2,2)
srn.distplot(data.loc[data['feed'] == 'casein'].weight).set_title('Caseina')
plt.subplot(3,2,3)
srn.distplot(data.loc[data['feed'] == 'linseed'].weight).set_title('Linseed')
plt.subplot(3,2,4)
srn.distplot(data.loc[data['feed'] == 'meatmeal'].weight).set_title('Meatmeal')
plt.subplot(3,2,5)
srn.distplot(data.loc[data['feed'] == 'soybean'].weight).set_title('Soybean')
plt.subplot(3,2,6)
srn.distplot(data.loc[data['feed'] == 'sunflower'].weight).set_title('Sunflower')
plt.tight_layout()
# Out:
# C:\Users\rocha\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\rocha\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...
