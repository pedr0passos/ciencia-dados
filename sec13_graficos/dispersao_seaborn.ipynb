# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('co2.csv')
data
# Out:
#    Plant         Type   Treatment  conc  uptake
# 0    Qn1       Quebec  nonchilled    95    16.0
# 1    Qn1       Quebec  nonchilled   175    30.4
# 2    Qn1       Quebec  nonchilled   250    34.8
# 3    Qn1       Quebec  nonchilled   350    37.2
# 4    Qn1       Quebec  nonchilled   500    35.3
# ..   ...          ...         ...   ...     ...
# 79   Mc3  Mississippi     chilled   250    17.9
# 80   Mc3  Mississippi     chilled   350    17.9
# 81   Mc3  Mississippi     chilled   500    17.9
# 82   Mc3  Mississippi     chilled   675    18.9
# 83   Mc3  Mississippi     chilled  1000    19.9
#
# [84 rows x 5 columns]

# %%
# grafico de dispersao utilizando os atributos conc e uptake, agrupamento pelo type
sb.scatterplot(data.conc, data.uptake, hue = data.Type)
# Out:
# C:\Users\rocha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='conc', ylabel='uptake'>

# %%
# selecao de registros especificos da base de dados ( quebec e mississipi )
q = data.loc[data['Type'] == 'Quebec']
m = data.loc[data['Type'] == 'Mississippi']

# %%
plt.figure()
plt.subplot(1,2,1)
sb.scatterplot(q.conc, q.uptake).set_title('Quebec')
plt.subplot(1,2,2)
sb.scatterplot(m.conc, m.uptake).set_title('Mississippi')
plt.tight_layout()
# Out:
# C:\Users\rocha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\rocha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# refrigerado e não refrigerado
ch = data.loc[data['Treatment'] == 'chilled']
nc = data.loc[data['Treatment'] == 'nonchilled']

# %%
plt.figure()
plt.subplot(1,2,1)
sb.scatterplot(ch.conc, ch.uptake).set_title('Chilled')
plt.subplot(1,2,2)
sb.scatterplot(nc.conc, nc.uptake).set_title('Non Chilled')
plt.tight_layout()
# Out:
# C:\Users\rocha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\rocha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# carregamento de outro arquivo, cancer de esofago
data2 = pd.read_csv('esoph.csv')
data2
# Out:
#     agegp      alcgp     tobgp  ncases  ncontrols
# 0   25-34  0-39g/day  0-9g/day       0         40
# 1   25-34  0-39g/day     10-19       0         10
# 2   25-34  0-39g/day     20-29       0          6
# 3   25-34  0-39g/day       30+       0          5
# 4   25-34      40-79  0-9g/day       0         27
# ..    ...        ...       ...     ...        ...
# 83    75+      40-79       30+       1          1
# 84    75+     80-119  0-9g/day       1          1
# 85    75+     80-119     10-19       1          1
# 86    75+       120+  0-9g/day       2          2
# 87    75+       120+     10-19       1          1
#
# [88 rows x 5 columns]

# %%
# grafico entre os atributos 'alcgp' e 'ncontrols'
sb.catplot(x = 'alcgp', y='ncontrols', data = data2, jitter = False)

# %%
sb.catplot(x = 'alcgp', y='ncontrols', data = data2, jitter = False, col='tobgp')
